# %%
# %%sh
# conda list
# Out:
# # packages in environment at e:\PortableApps\Anaconda3:
# #
# _license                  1.1                      py35_1
# _nb_ext_conf              0.3.0                    py35_0
# alabaster                 0.7.9                    py35_0
# anaconda                  4.2.0               np111py35_0
# anaconda-clean            1.0.0                    py35_0
# anaconda-client           1.5.1                    py35_0
# anaconda-navigator        1.3.1                    py35_0
# argcomplete               1.0.0                    py35_1
# astroid                   1.4.7                    py35_0
# astropy                   1.2.1               np111py35_0
# babel                     2.3.4                    py35_0
# backports                 1.0                      py35_0
# beautifulsoup4            4.5.1                    py35_0
# bitarray                  0.8.1                    py35_1
# blaze                     0.10.1                   py35_0
# ...

# %%
import yaml

# %%
pgs = yaml.load(open("planetary_gear_spec.yaml", 'rb'))

# %%
pgs['Planetary Gear Assy']['parts']
# Out:
# {'bearings': {'material': 'cold-rolled steel', 'type': 'journal'},
#  'carrier': {'diameter': '3.133/2 + 5.326/2'},
#  'outer-ring-gear': {'configuration': 'internal teeth',
#   'material': 'forged steel',
#   'pitch-diameter': '5.326/2 + 3.133',
#   'role': 'driving',
#   'shape': 'ring',
#   'tooth-count': 24},
#  'planet-gear': {'configuration': 'external teeth',
#   'material': 'forged steel',
#   'pitch-diameter': 3.133,
#   'role': 'driven reducing',
#   'shape': 'ring or solid',
#   'tooth-count': 18},
#  'sun-gear': {'configuration': 'external teeth',
#   'material': 'forged steel',
#   'pitch-diameter': 5.326,
#   'role': 'driving',
#   'shape': 'ring',
#   'tooth-count': 24}}
